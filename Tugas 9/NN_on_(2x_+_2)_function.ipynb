# %% [markdown]
# Nama:Nadhifi Qurrunul B F H
#
# Nim  : 1103204156
#
# ## **NN on (2x + 2) function**

# %%
# Install TensorFlow
# pip install tensorflow

# %%
# Import library yang dibutuhkan
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
# Fungsi untuk menghasilkan data latih
def generate_data():
    X = np.random.uniform(-10, 10, 1000)  # Data latih pada rentang -10 hingga 10
    y = 2 * X + 2 + np.random.normal(0, 2, 1000)  # Fungsi 2x + 2 dengan noise

    return X, y

# Membuat data latih
X_train, y_train = generate_data()

# %%
# Membangun model jaringan saraf
model = tf.keras.Sequential([
    tf.keras.layers.Dense(units=1, input_shape=(1,))
])

# %%
# Mengompilasi model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Melatih model dengan data latih
model.fit(X_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 32/32 [==============================] - 0s 2ms/step - loss: 37.5269
# Epoch 2/50
# 32/32 [==============================] - 0s 2ms/step - loss: 35.5032
# Epoch 3/50
# 32/32 [==============================] - 0s 2ms/step - loss: 33.5722
# Epoch 4/50
# 32/32 [==============================] - 0s 2ms/step - loss: 31.7397
# Epoch 5/50
# 32/32 [==============================] - 0s 2ms/step - loss: 29.9842
# Epoch 6/50
# 32/32 [==============================] - 0s 2ms/step - loss: 28.3198
# Epoch 7/50
# 32/32 [==============================] - 0s 2ms/step - loss: 26.7348
# Epoch 8/50
# 32/32 [==============================] - 0s 2ms/step - loss: 25.2557
# Epoch 9/50
# 32/32 [==============================] - 0s 2ms/step - loss: 23.8589
# Epoch 10/50
# 32/32 [==============================] - 0s 2ms/step - loss: 22.5264
# Epoch 11/50
# 32/32 [==============================] - 0s 2ms/step - loss: 21.2698
# Epoch 12/50
# 32/32 [==============================] - 0s 2ms/step - loss: 20.0793
# Epoch 13/50
# 32/32 [==============================] - 0s 2ms/step - loss: 18.9659
# Epoch 14/50
# 32/32 [==============================] - 0s 2ms/step - loss: 17.9227
# Epoch 15/50
# 32/32 [==============================] - 0s 2ms/step - loss: 16.9242
# Epoch 16/50
# 32/32 [==============================] - 0s 2ms/step - loss: 16.0063
# Epoch 17/50
# 32/32 [==============================] - 0s 2ms/step - loss: 15.1252
# Epoch 18/50
# 32/32 [==============================] - 0s 2ms/step - loss: 14.2982
# Epoch 19/50
# 32/32 [==============================] - 0s 2ms/step - loss: 13.5307
# Epoch 20/50
# 32/32 [==============================] - 0s 1ms/step - loss: 12.8277
# Epoch 21/50
# 32/32 [==============================] - 0s 2ms/step - loss: 12.1549
# Epoch 22/50
# 32/32 [==============================] - 0s 2ms/step - loss: 11.5345
# Epoch 23/50
# 32/32 [==============================] - 0s 2ms/step - loss: 10.9590
# Epoch 24/50
# 32/32 [==============================] - 0s 2ms/step - loss: 10.4273
# Epoch 25/50
# 32/32 [==============================] - 0s 2ms/step - loss: 9.9295
# Epoch 26/50
# 32/32 [==============================] - 0s 2ms/step - loss: 9.4806
# Epoch 27/50
# 32/32 [==============================] - 0s 2ms/step - loss: 9.0482
# Epoch 28/50
# 32/32 [==============================] - 0s 2ms/step - loss: 8.6545
# Epoch 29/50
# 32/32 [==============================] - 0s 2ms/step - loss: 8.2899
# Epoch 30/50
# 32/32 [==============================] - 0s 2ms/step - loss: 7.9556
# Epoch 31/50
# 32/32 [==============================] - 0s 2ms/step - loss: 7.6516
# Epoch 32/50
# 32/32 [==============================] - 0s 2ms/step - loss: 7.3699
# Epoch 33/50
# 32/32 [==============================] - 0s 2ms/step - loss: 7.1133
# Epoch 34/50
# 32/32 [==============================] - 0s 2ms/step - loss: 6.8743
# Epoch 35/50
# 32/32 [==============================] - 0s 2ms/step - loss: 6.6591
# Epoch 36/50
# 32/32 [==============================] - 0s 2ms/step - loss: 6.4634
# Epoch 37/50
# 32/32 [==============================] - 0s 2ms/step - loss: 6.2851
# Epoch 38/50
# 32/32 [==============================] - 0s 2ms/step - loss: 6.1211
# Epoch 39/50
# 32/32 [==============================] - 0s 2ms/step - loss: 5.9689
# Epoch 40/50
# 32/32 [==============================] - 0s 2ms/step - loss: 5.8299
# Epoch 41/50
# 32/32 [==============================] - 0s 2ms/step - loss: 5.7024
# Epoch 42/50
# 32/32 [==============================] - 0s 2ms/step - loss: 5.5936
# Epoch 43/50
# 32/32 [==============================] - 0s 2ms/step - loss: 5.4898
# Epoch 44/50
# 32/32 [==============================] - 0s 2ms/step - loss: 5.3980
# Epoch 45/50
# 32/32 [==============================] - 0s 1ms/step - loss: 5.3125
# Epoch 46/50
# 32/32 [==============================] - 0s 2ms/step - loss: 5.2361
# Epoch 47/50
# 32/32 [==============================] - 0s 2ms/step - loss: 5.1667
# Epoch 48/50
# 32/32 [==============================] - 0s 2ms/step - loss: 5.1025
# Epoch 49/50
# 32/32 [==============================] - 0s 2ms/step - loss: 5.0436
# Epoch 50/50
# 32/32 [==============================] - 0s 2ms/step - loss: 4.9904

# %%
# Plot sejarah pelatihan
plt.plot(history.history['loss'])
plt.title('Training Loss')
plt.xlabel('Epoch')
plt.ylabel('Mean Squared Error')
plt.show()

# %%
# Melakukan prediksi menggunakan model yang telah dilatih
X_test = np.linspace(-5, 5, 100).reshape(-1, 1)
y_pred = model.predict(X_test)
# Out:
# WARNING:tensorflow:5 out of the last 14 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7a00eaeb8a60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 4/4 [==============================] - 0s 3ms/step

# %%
# Plot fungsi asli dan nilai yang diprediksi
plt.scatter(X_train, y_train, label='Training Data')
plt.plot(X_test, y_pred, color='red', label='Predicted Function: 2x + 2')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
